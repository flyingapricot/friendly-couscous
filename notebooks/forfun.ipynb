# %%
import numpy as np
from numpy.linalg import inv, matrix_rank, det
import matplotlib.pyplot as plt
from MSESolver import *
from PolyTX import *
from LESolver import *
from yuwen import *

X = np.array([[1,2],[0,6],[1,0],[0,5],[1,7]])
y = np.array([[1],[2],[3],[4],[5]])

new_point = np.array([[1,3]])

output, MSE = predict_and_calculate_mse(X,y,new_point)

# # add bias t
print("mean squared error:",MSE) 
print(output)# # # # o train data
# bias = np.ones((np.shape(X)[0],1))
# X_ = np.hstack((bias, X))

# print("X_= \n", X_)

# # Solve Linear Equations for w
# w = solveLE(X_,y)

# y_pred = X_@w


# print("\n")
# mse = np.mean((np.array(y) - np.array(y_pred))**2)

# print(mse)

# print("\n")

# print(y_pred)
# Out:
# mean squared error: 1.388679245283019
# [3.]
